# %%
# win percentage
import requests
from bs4 import BeautifulSoup

def scrape_nba_win_percentages(urls):
    data = {}

    for url in urls:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the table
        table = soup.find('table')
        if table:
            rows = []
            for row in table.find_all('tr')[1:]:  # Skip the header row
                cols = row.find_all('td')
                # Extract only the first three columns
                row_data = [col.text.strip() for col in cols[:3]]
                rows.append(row_data)
            data[url] = rows
        else:
            data[url] = "Table not found"

    return data
urls = [
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2004-06-16",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2005-06-24",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2006-06-21",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2007-06-15",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2008-06-18",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2009-06-15",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2010-06-18",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2011-06-12",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2012-06-21",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2013-06-20",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2014-06-15",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2015-06-16",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2016-06-20",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2017-06-13",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2018-06-09",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2019-06-14",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2020-10-12",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2021-07-21",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2022-06-17",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2023-06-13",
    "https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2023-12-18"
]

scraped_data = scrape_nba_win_percentages(urls)

# Print the scraped data
for url, table_data in scraped_data.items():
    print(f"Data from {url}:")
    for row in table_data:
        print(row)
    print("\n")
# Out:
# Data from https://www.teamrankings.com/nba/stat/win-pct-all-games?date=2004-06-16:
# ['1', 'Indiana', '0.725']
# ['2', 'San Antonio', '0.685']
# ['3', 'Minnesota', '0.680']
# ['4', 'Detroit', '0.667']
# ['5', 'LA Lakers', '0.664']
# ['6', 'Sacramento', '0.660']
# ['7', 'Dallas', '0.609']
# ['8', 'Memphis', '0.581']
# ['9', 'Brooklyn', '0.581']
# ['10', 'Houston', '0.529']
# ['11', 'Utah', '0.512']
# ['12', 'Denver', '0.506']
# ['13', 'Miami', '0.505']
# ['14', 'Portland', '0.500']
# ['15', 'New Orleans', '0.494']
# ['16', 'Milwaukee', '0.483']
# ['17', 'New York', '0.454']
# ['18', 'Golden State', '0.451']
# ['18', 'Okla City', '0.451']
# ['20', 'Cleveland', '0.427']
# ['21', 'Boston', '0.419']
# ['22', 'Toronto', '0.402']
# ['22', 'Philadelphia', '0.402']
# ['24', 'Phoenix', '0.354']
# ['25', 'Atlanta', '0.342']
# ['25', 'LA Clippers', '0.342']
# ['27', 'Washington', '0.305']
# ['28', 'Chicago', '0.281']
# ['29', 'Orlando', '0.256']
#
#
# ...

# %%
#effective field goal percentage
import requests
from bs4 import BeautifulSoup

def scrape_nba_efg_percentages(urls):
    data = {}

    for url in urls:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the table
        table = soup.find('table')
        if table:
            rows = []
            for row in table.find_all('tr')[1:]:  # Skip the header row
                cols = row.find_all('td')
                # Extract only the first three columns
                row_data = [col.text.strip() for col in cols[:3]]
                rows.append(row_data)
            data[url] = rows
        else:
            data[url] = "Table not found"

    return data

# URLs to scrape
efg_urls = [
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2004-06-16",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2005-06-24",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2006-06-21",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2007-06-15",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2008-06-18",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2009-06-15",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2010-06-18",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2011-06-12",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2012-06-21",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2013-06-20",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2014-06-15",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2015-06-16",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2016-06-20",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2017-06-13",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2018-06-09",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2019-06-14",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2020-10-12",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2021-07-21",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2022-06-17",
    "https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2023-12-18"
]

# Scraping data from all URLs
scraped_efg_data = scrape_nba_efg_percentages(efg_urls)

# Print the scraped data
for url, table_data in scraped_efg_data.items():
    print(f"Data from {url}:")
    for row in table_data:
        print(row)
    print("\n")
# Out:
# Data from https://www.teamrankings.com/nba/stat/effective-field-goal-pct?date=2004-06-16:
# ['1', 'Sacramento', '50.1%']
# ['2', 'Okla City', '50.1%']
# ['3', 'Dallas', '49.0%']
# ['4', 'Minnesota', '48.5%']
# ['5', 'Boston', '48.5%']
# ['6', 'Houston', '48.2%']
# ['7', 'LA Lakers', '48.0%']
# ['8', 'Portland', '47.8%']
# ['9', 'Memphis', '47.7%']
# ['10', 'Milwaukee', '47.5%']
# ['11', 'San Antonio', '47.5%']
# ['12', 'Phoenix', '47.5%']
# ['13', 'Golden State', '47.5%']
# ['14', 'New York', '47.1%']
# ['15', 'Brooklyn', '46.9%']
# ['16', 'Indiana', '46.7%']
# ['17', 'Denver', '46.6%']
# ['18', 'Atlanta', '46.5%']
# ['19', 'Orlando', '46.1%']
# ['20', 'Miami', '45.9%']
# ['21', 'New Orleans', '45.7%']
# ['22', 'Detroit', '45.7%']
# ['23', 'Utah', '45.6%']
# ['24', 'Philadelphia', '45.6%']
# ['25', 'Toronto', '45.4%']
# ['26', 'Washington', '45.4%']
# ['27', 'LA Clippers', '45.3%']
# ['28', 'Cleveland', '45.1%']
# ['29', 'Chicago', '44.6%']
#
#
# ...

# %%
#defensive efficiency
import requests
from bs4 import BeautifulSoup

def scrape_nba_defensive_efficiency(urls):
    data = {}

    for url in urls:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the table
        table = soup.find('table')
        if table:
            rows = []
            for row in table.find_all('tr')[1:]:  # Skip the header row
                cols = row.find_all('td')
                # Extract only the first three columns
                row_data = [col.text.strip() for col in cols[:3]]
                rows.append(row_data)
            data[url] = rows
        else:
            data[url] = "Table not found"

    return data

# URLs to scrape
defensive_efficiency_urls = [
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2004-06-16",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2005-06-24",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2006-06-21",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2007-06-15",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2008-06-18",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2009-06-15",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2010-06-18",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2011-06-12",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2012-06-21",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2013-06-20",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2014-06-15",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2015-06-16",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2016-06-20",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2017-06-13",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2018-06-09",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2019-06-14",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2020-10-12",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2021-07-21",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2022-06-17",
    "https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2023-12-18"
]

# Scraping data from all URLs
scraped_defensive_efficiency_data = scrape_nba_defensive_efficiency(defensive_efficiency_urls)

# Print the scraped data
for url, table_data in scraped_defensive_efficiency_data.items():
    print(f"Data from {url}:")
    for row in table_data:
        print(row)
    print("\n")
# Out:
# Data from https://www.teamrankings.com/nba/stat/defensive-efficiency?date=2004-06-16:
# ['1', 'San Antonio', '0.921']
# ['2', 'Detroit', '0.921']
# ['3', 'Indiana', '0.941']
# ['4', 'Brooklyn', '0.949']
# ['5', 'Houston', '0.964']
# ['6', 'Minnesota', '0.971']
# ['7', 'Toronto', '0.978']
# ['8', 'Miami', '0.980']
# ['9', 'LA Lakers', '0.981']
# ['10', 'New Orleans', '0.990']
# ['11', 'Philadelphia', '0.991']
# ['12', 'Memphis', '0.996']
# ['13', 'Denver', '0.997']
# ['14', 'Utah', '1.000']
# ['15', 'New York', '1.002']
# ['16', 'Chicago', '1.005']
# ['17', 'Boston', '1.009']
# ['18', 'Golden State', '1.010']
# ['19', 'Cleveland', '1.010']
# ['20', 'Sacramento', '1.013']
# ['21', 'Washington', '1.017']
# ['22', 'Portland', '1.022']
# ['23', 'Phoenix', '1.024']
# ['24', 'Milwaukee', '1.024']
# ['25', 'Atlanta', '1.030']
# ['26', 'Dallas', '1.041']
# ['27', 'Okla City', '1.046']
# ['28', 'LA Clippers', '1.050']
# ['29', 'Orlando', '1.069']
#
#
# ...

# %%
#opponent field goal percentage
import requests
from bs4 import BeautifulSoup

def scrape_nba_opponent_efg_percentages(urls):
    data = {}

    for url in urls:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the table
        table = soup.find('table')
        if table:
            rows = []
            for row in table.find_all('tr')[1:]:  # Skip the header row
                cols = row.find_all('td')
                # Extract only the first three columns
                row_data = [col.text.strip() for col in cols[:3]]
                rows.append(row_data)
            data[url] = rows
        else:
            data[url] = "Table not found"

    return data

# URLs to scrape
opponent_efg_urls = [
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2004-06-16",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2005-06-24",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2006-06-21",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2007-06-15",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2008-06-18",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2009-06-15",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2010-06-18",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2011-06-12",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2012-06-21",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2013-06-20",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2014-06-15",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2015-06-16",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2016-06-20",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2017-06-13",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2018-06-09",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2019-06-14",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2020-10-12",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2021-07-21",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2022-06-17",
    "https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2023-06-13"
]

# Scraping data from all URLs
scraped_opponent_efg_data = scrape_nba_opponent_efg_percentages(opponent_efg_urls)

# Print the scraped data
for url, table_data in scraped_opponent_efg_data.items():
    print(f"Data from {url}:")
    for row in table_data:
        print(row)
    print("\n")
# Out:
# Data from https://www.teamrankings.com/nba/stat/opponent-effective-field-goal-pct?date=2004-06-16:
# ['1', 'Detroit', '43.7%']
# ['2', 'San Antonio', '43.8%']
# ['3', 'Minnesota', '44.7%']
# ['4', 'Houston', '44.8%']
# ['5', 'Toronto', '44.9%']
# ['6', 'Indiana', '45.3%']
# ['7', 'Brooklyn', '45.5%']
# ['8', 'Miami', '46.1%']
# ['9', 'New York', '46.3%']
# ['10', 'Philadelphia', '46.7%']
# ['11', 'Utah', '46.8%']
# ['12', 'LA Lakers', '46.8%']
# ['13', 'Memphis', '46.9%']
# ['14', 'Chicago', '46.9%']
# ['15', 'Cleveland', '46.9%']
# ['16', 'New Orleans', '47.2%']
# ['17', 'Golden State', '47.6%']
# ['18', 'Atlanta', '47.6%']
# ['19', 'Sacramento', '47.9%']
# ['20', 'Boston', '48.0%']
# ['21', 'Portland', '48.2%']
# ['22', 'Phoenix', '48.2%']
# ['23', 'Denver', '48.3%']
# ['24', 'Washington', '48.6%']
# ['25', 'Milwaukee', '48.6%']
# ['26', 'Okla City', '48.7%']
# ['27', 'LA Clippers', '49.4%']
# ['28', 'Dallas', '49.7%']
# ['29', 'Orlando', '50.2%']
#
#
# ...

# %%
# NBA Team Average Scoring Margin
import requests
from bs4 import BeautifulSoup

def scrape_nba_average_scoring_margin(urls):
    data = {}

    for url in urls:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find the table
        table = soup.find('table')
        if table:
            rows = []
            for row in table.find_all('tr')[1:]:  # Skip the header row
                cols = row.find_all('td')
                # Extract only the first three columns
                row_data = [col.text.strip() for col in cols[:3]]
                rows.append(row_data)
            data[url] = rows
        else:
            data[url] = "Table not found"

    return data

# URLs to scrape
average_scoring_margin_urls = [
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2004-06-16",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2005-06-24",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2006-06-21",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2007-06-15",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2008-06-18",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2009-06-15",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2010-06-18",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2011-06-12",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2012-06-21",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2013-06-20",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2014-06-15",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2015-06-16",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2016-06-20",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2017-06-13",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2018-06-09",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2019-06-14",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2020-10-12",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2021-07-21",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2022-06-17",
    "https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2023-06-13"
]

# Scraping data from all URLs
scraped_average_scoring_margin_data = scrape_nba_average_scoring_margin(average_scoring_margin_urls)

# Print the scraped data
for url, table_data in scraped_average_scoring_margin_data.items():
    print(f"Data from {url}:")
    for row in table_data:
        print(row)
    print("\n")
# Out:
# Data from https://www.teamrankings.com/nba/stat/average-scoring-margin?date=2004-06-16:
# ['1', 'San Antonio', '+6.8']
# ['2', 'Detroit', '+6.0']
# ['3', 'Indiana', '+5.5']
# ['4', 'Minnesota', '+4.5']
# ['5', 'Sacramento', '+4.4']
# ['6', 'Dallas', '+4.3']
# ['7', 'LA Lakers', '+3.3']
# ['8', 'Brooklyn', '+2.5']
# ['9', 'Memphis', '+1.7']
# ['10', 'Houston', '+1.3']
# ['11', 'Denver', '+0.8']
# ['12', 'Miami', '+0.5']
# ['13', 'Milwaukee', '+0.3']
# ['14', 'New Orleans', '-0.3']
# ['15', 'Okla City', '-0.6']
# ['16', 'Golden State', '-0.7']
# ['17', 'Utah', '-1.2']
# ['18', 'Portland', '-1.3']
# ['19', 'New York', '-2.0']
# ['20', 'Boston', '-2.2']
# ['21', 'Philadelphia', '-2.5']
# ['22', 'Cleveland', '-2.6']
# ['23', 'Toronto', '-3.0']
# ['24', 'Phoenix', '-3.7']
# ['25', 'LA Clippers', '-4.6']
# ['26', 'Atlanta', '-4.6']
# ['27', 'Washington', '-5.6']
# ['28', 'Chicago', '-6.4']
# ['29', 'Orlando', '-7.0']
#
#
# ...
